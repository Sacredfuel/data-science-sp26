# %% [markdown]
# ## Project Overview
#
# | Deadline | Deliverable         | Points  | Submission Window Opens |
# | -------- | ------------------- | ------- | ----------------------- |
# | Tuesday, 3 March      | Opt-in              | 0       | Tuesday, 24 Febuary                     |
# | Thursday, 19 March      | Proposal            | 50      | Tuesday, 10 March                   |
# | Tuesday, April 7      | Interim Check-In    | 25      | Tuesday, March 31                     |
# | TBA      | Complete Project    | 100     | TBA                     |
# | TBA      | Presentation Slides | 25      | TBA                     |
# |          | **Total Points**    | **200** |                         |

# %% [markdown]
# The optional project must:
# - Use publicly available data, ideally from Kaggle or NYC Open Data.
# - Employ a predictive model.
# - Visualizations that include summary statistics plots, map graphs, and model perfomance plots.
